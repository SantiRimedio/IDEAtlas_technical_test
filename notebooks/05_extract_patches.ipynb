# %%
# Install required packages
# !pip install rasterio geopandas tqdm

# Import required libraries
import os
import sys
import numpy as np
import rasterio
from rasterio.windows import Window
import geopandas as gpd
from tqdm import tqdm
import zipfile
import shutil

# %%
import sys, os
PROJECT_ROOT = os.path.abspath(os.path.join(os.path.dirname('__file__'), '..'))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from src.preprocessing.extract_patch import extract_patches

# %% [markdown]
#    /content/drive/MyDrive/Fine-Tuning-Workflow/Downloads/S2/density_multiscale_AMBA//density_stack_multiband.tif

# %%
# Input files
s2_raster = '/content/drive/MyDrive/Fine-Tuning-Workflow/Downloads/S2/s2_2020_partidos_ambas.tif'
morphometrics_raster = '/content/drive/MyDrive/Fine-Tuning-Workflow/Downloads/S2/s2_2025_building_density_updated.tif'
target_raster = '/content/drive/MyDrive/Fine-Tuning-Workflow/Downloads/S2/reference_labels_partidos_AMBA.tif'
grid_file = '/content/drive/MyDrive/Fine-Tuning-Workflow/Downloads/S2/grid_partidos_amba_sample_50.geojson'

# Output directories
base_output = '/content/drive/MyDrive/ML_Inference_Data/partidos_amba_2020_sample_50'
s2_output = os.path.join(base_output, 'S2')
morpho_output = os.path.join(base_output, 'DEN')
target_output = os.path.join(base_output, 'RF')

# Extraction parameters
patch_size = 128
nodata_value = None  # Use each raster's nodata value

# %%
# S2 extraction
#extract_patches(s2_raster, grid_file, s2_output, patch_size, nodata_value, True, 'S2', allow_negative=True, save_validation_log=False)

# Morphometrics extraction
extract_patches(morphometrics_raster, grid_file, morpho_output, patch_size, nodata_value, True, 'DEN',allow_negative=True, save_validation_log=False)

# Target extraction
#extract_patches(target_raster, grid_file, target_output, patch_size, nodata_value, True, 'RF', allow_negative=True, save_validation_log=False)
# Out:
# Raster Info: 7 band(s), dtype: float32, nodata: None
# Using prefix: DEN
# Validation criteria:
#   - Min valid ratio: 95.0%
#   - Allow negative values: True
#
# Processing 1747 train patches...
# train: 1747 valid: 100%|██████████| 1747/1747 [02:49<00:00, 10.31it/s]
# Processing 384 val patches...
# val: 384 valid: 100%|██████████| 384/384 [00:33<00:00, 11.44it/s]
# Processing 406 test patches...
# test: 406 valid: 100%|██████████| 406/406 [00:37<00:00, 10.88it/s]
# ...
# EXTRACTION SUMMARY
# ...
# Total patches processed: 2537
# Total patches extracted: 2537 (100.0%)
# Total patches skipped: 0 (0.0%)
#
# train: 1747 extracted,    0 skipped (100.0% valid)
#   val:  384 extracted,    0 skipped (100.0% valid)
#  test:  406 extracted,    0 skipped (100.0% valid)

# %%
# Input files
#s2_raster = '/content/drive/MyDrive/Fine-Tuning-Workflow/Downloads/S2/s2_2020_partidos_ambas.tif'
morphometrics_raster = '/content/drive/MyDrive/Fine-Tuning-Workflow/Downloads/S2/density_multiscale_AMBA/density_stack_multiband.tif'
#target_raster = '/content/drive/MyDrive/Fine-Tuning-Workflow/Downloads/S2/reference_labels_partidos_AMBA.tif'
grid_file = '/content/drive/MyDrive/ML_Inference_Data/Grid_BuenosAires_renamed.geojson'

# Output directories
base_output = '/content/drive/MyDrive/ML_Inference_Data/new_morphometrics_multiband'
#s2_output = os.path.join(base_output, 'S2')
morpho_output = os.path.join(base_output, 'DEN')
#target_output = os.path.join(base_output, 'RF')

# Extraction parameters
patch_size = 128
nodata_value = None  # Use each raster's nodata value

# %%
morpho_output = os.path.join(base_output, 'DEN')
target_output = os.path.join(base_output, 'RF')

extract_patches(morphometrics_raster, grid_file, morpho_output, patch_size, nodata_value, True, 'DEN')

# Target extraction
extract_patches(target_raster, grid_file, target_output, patch_size, nodata_value, True, 'RF')
